# %%
# import libraries
import psycopg2
import pandas as pd

# %% [markdown]
# # IMPORT DATASETS (Accounts Country, Data and Series)

# %% [markdown]
# ### Accounts Country

# %%
# import accounts Country
AccountsCountry = pd.read_csv("C:/jopeca/datasets/WDICountry.csv")

# %%
# show data head to see the intire panorama of this dataset
AccountsCountry.head()
# Out:
#   Country Code                   Short Name                   Table Name  \
# 0          ABW                        Aruba                        Aruba
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
# 3          AFW   Africa Western and Central   Africa Western and Central
# 4          AGO                       Angola                       Angola
#
#                       Long Name 2-alpha code   Currency Unit  \
# 0                         Aruba           AW   Aruban florin
# 1   Africa Eastern and Southern           ZH             NaN
# 2  Islamic State of Afghanistan           AF  Afghan afghani
# 3    Africa Western and Central           ZI             NaN
# 4   People's Republic of Angola           AO  Angolan kwanza
#
#                                        Special Notes  \
# 0                                                NaN
# ...

# %%
# Show only columns
AccountsCountry.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data', 'Unnamed: 30'],
#       dtype='object')

# %%
# After saw the columns, now let clean de dataset to filter only columns that we need to use
AccountsCountryFiltering = AccountsCountry[['Country Code', 'Short Name', 'Table Name', 'Long Name', 'Currency Unit']]

# %%
#Show how dataset bcome after filtering some columns
AccountsCountryFiltering.head()
# Out:
#   Country Code                   Short Name                   Table Name  \
# 0          ABW                        Aruba                        Aruba
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
# 3          AFW   Africa Western and Central   Africa Western and Central
# 4          AGO                       Angola                       Angola
#
#                       Long Name   Currency Unit
# 0                         Aruba   Aruban florin
# 1   Africa Eastern and Southern             NaN
# 2  Islamic State of Afghanistan  Afghan afghani
# 3    Africa Western and Central             NaN
# 4   People's Republic of Angola  Angolan kwanza

# %% [markdown]
# ### Accounts Data

# %%
# Import Accounts Data
AccountsData = pd.read_csv("C:/jopeca/datasets/WDIData.csv")

# %%
AccountsData.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.789043  17.196986  17.597176
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.397917   6.580066   6.786218
# ...

# %%
# Show colums
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
#Filter only columns that's we use
AccountsDataFilter = AccountsData[['Country Name', 'Country Code', 'Indicator Name', \
     'Indicator Code', '1990', '1995', '2000', '2005', '2010', '2015', '2020']]

# %%
AccountsDataFilter.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1990  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1995       2000       2005       2010       2015       2020
# 0   NaN  11.569626  13.374963  15.551005  17.597176  19.501837
# 1   NaN   3.545501   4.536031   5.759078   6.786218   7.599289
# ...

# %% [markdown]
# ### Accounts Series

# %%
AccountsSeries = pd.read_csv("C:/jopeca/datasets/WDISeries.csv")

# %%
AccountsSeries.head()
# Out:
#          Series Code                                 Topic  \
# 0     AG.AGR.TRAC.NO  Environment: Agricultural production
# 1  AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2     AG.CON.FERT.ZS  Environment: Agricultural production
# 3     AG.LND.AGRI.K2                 Environment: Land use
# 4     AG.LND.AGRI.ZS                 Environment: Land use
#
#                                       Indicator Name Short definition  \
# 0                   Agricultural machinery, tractors              NaN
# 1  Fertilizer consumption (% of fertilizer produc...              NaN
# 2  Fertilizer consumption (kilograms per hectare ...              NaN
# 3                         Agricultural land (sq. km)              NaN
# 4                 Agricultural land (% of land area)              NaN
#
#                                      Long definition Unit of measure  \
# 0  Agricultural machinery refers to the number of...             NaN
# ...

# %%
AccountsSeries.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
# Filtering
AccountsSeriesFilter = AccountsSeries[['Series Code', 'Topic', 'Indicator Name', 'Short definition']]

# %%
AccountsSeriesFilter.head()
# Out:
#          Series Code                                 Topic  \
# 0     AG.AGR.TRAC.NO  Environment: Agricultural production
# 1  AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2     AG.CON.FERT.ZS  Environment: Agricultural production
# 3     AG.LND.AGRI.K2                 Environment: Land use
# 4     AG.LND.AGRI.ZS                 Environment: Land use
#
#                                       Indicator Name Short definition
# 0                   Agricultural machinery, tractors              NaN
# 1  Fertilizer consumption (% of fertilizer produc...              NaN
# 2  Fertilizer consumption (kilograms per hectare ...              NaN
# 3                         Agricultural land (sq. km)              NaN
# 4                 Agricultural land (% of land area)              NaN

# %% [markdown]
# # Create a database
# ### Create a connection , cursor to execute the connection

# %%
#establishing the connection
conexao = psycopg2.connect( database="postgres", user='postgres', password='1234aBCD4321.', host='127.0.0.1', port= '5432'
    )
conexao.autocommit = True


#Creating a cursor object using the cursor() method
cursr = conexao.cursor()

#Preparing query to create a database
sql = '''CREATE database contas''';

#Creating a database
cursr.execute(sql)
print("Database created successfully........")

    #Closing the connection
conexao.close()

# %% [markdown]
# # Create Tables
